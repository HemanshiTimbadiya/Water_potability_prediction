# %% [markdown]
# <h1 style="background-color:#338aff; color:white; font-family:'calibri', sans-serif; font-size:300% ; text-align:center; padding:15px; border-radius:15px 50px;">
#  🚰 Water Potability Prediction 💧
# </h1>

# %% [markdown]
# ![Water Image](https://github.com/HemanshiTimbadiya/photo/blob/main/water1.jpg?raw=true )

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; font-size:120%; text-align:left ;background-color:#e2e5e9; color :black">
#
# <h3 align="left">Goal :</font></h3>
#           The goal of the water potability project is to assess and predict the safety of drinking water by analyzing various chemical and physical parameters. Through exploratory data analysis (EDA), the project aims to uncover patterns and trends that influence water quality, while developing and optimizing machine learning models, such as Support Vector Classifier and Random Forest, to ensure accurate predictions. By addressing class imbalance and employing hyperparameter tuning, the project seeks to enhance model performance and identify key water quality indicators through feature importance analysis. Ultimately, the project aims to provide actionable insights for stakeholders, raise community awareness about water safety, and support informed decision-making regarding public health.

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; font-size:115%; text-align:left ;background-color:#e2e5e9; color :black">
#     <h3 align="left"><font>Project Objectives:</font></h3>
#
# * __Data Exploration and Preprocessing__:
#   - Load Data: Import the dataset using appropriate libraries.
#   - Handle Missing Values: Identify and address any missing data points through imputation or removal.
#   - Check Distributions: Visualize feature distributions to understand data characteristics.
#   - Address Outliers: Detect and manage outliers to improve model accuracy.
#   - Scale Features: Standardize or normalize features to ensure consistent scaling.</br>
#
#
# * __Feature Engineering__:
#   - Analyze Correlations: Evaluate relationships between features and the target variable.
#   - Create/Transform Features: Engineer new features or transform existing ones to enhance predictive power.</br>
#
#
# * __Handling Class Imbalance__:
#   - Balance Data: Apply techniques such as SMOTE to address any class imbalance in the dataset.</br>
#
#
# * __Model Selection and Training__:
#   - Split Data: Divide the data into training and testing sets.
#   - Train Multiple Models: Implement and compare classifiers like SVC, Random Forest, KNN, Decision Tree, and XGBoost using cross-validation.</br>
#
#
# * __Hyperparameter Tuning__:
#   - Optimize Models: Utilize GridSearchCV or RandomizedSearchCV for tuning hyperparameters.</br>
#
# * __Model Evaluation__:
#   - Assess Performance: Evaluate models using accuracy, precision, recall, F1-score, confusion matrices, ROC curves, and AUC scores.</br>
#
#
# * __Feature Importance__:
#   - Analyze Importance: For tree-based models, visualize and interpret feature importances to understand their impact on predictions.

# %% [markdown]
# <a id="contents_tabel"></a>
# <div style="border-radius:10px; padding: 15px; font-size:115%; text-align:left">
#
# <h3 align="left"><font>Table of Contents:</font></h3>
#
# * [Step 1 | Import Libraries](#import)
# * [Step 2 | Read Dataset](#read)
# * [Step 3 | Dataset Overview](#overview)
#     - [Step 3.1 | Dataset Basic Information](#basic)
#     - [Step 3.2 | Display the Datatypes of each column](#dtypes)
#     - [Step 3.3 | Summary Statistics for numerical Variables](#num_statistics)
# * [Step 4 | EDA](#eda)
#     - [Step 4.1 | Univariate Analysis](#univariate)
#         - [Step 4.1.1 | Check the distribution of continuous variables](#num_uni)
#         - [Step 4.1.2 | Check the distribution of categorial variables](#cat_uni)
#     - [Step 4.2 | Bivariate Analysis](#bivariate)
#         - [Step 4.2.1 | Check the distribution with target variable](#num_target)
#         - [Step 4.2.2 | Check correlation Matrix with Target Variable](#corr)
# * [Step 5 | Data Preprocessing](#preprocessing)
#     - [Step 5.1 | Check misiing values](#missing)
#     - [Step 5.2 | Outlier Treatment](#outlier)
#     - [Step 5.3 | Features Engineering](#eng)
#     - [Step 5.4 | Scale Features](#scale)
#     - [Step 5.5 | Handling Class Imbalance](#imbalance)
# * [Step 6 | Random Forest Model Building](#rf)
#     - [Step 6.1 | Random Forest Base Model Definition](#rf_base)
#     - [Step 6.2 | Random Forest Hyperparameter Tuning](#rf_hp)
#     - [Step 6.3 | Random Forest Model Evaluation](#rf_eval)
# * [Step 7 | SVC Model Building](#svc)
#     - [Step 7.1 | SVC Base Model Definition](#svc_base)
#     - [Step 7.2 | SVC Hyperparameter Tuning](#svc_hp)
#     - [Step 7.3 | SVC Model Evaluation](#svc_eval)
# * [Step 8 | XGBoost Model Building](#xgb)
#     - [Step 8.1 | XGBoost Base Model Definition](#xg_base)
#     - [Step 8.2 | XGBoost Hyperparameter Tuning](#xg_hp)
#     - [Step 8.3 | XGBoost Model Evaluation](#xg_eval)
# * [Step 9 | Decision Tree Model Building](#dt)
#     - [Step 9.1 | Decision Tree Base Model Definition](#dt_base)
#     - [Step 9.2 | Decision Tree Hyperparameter Tuning](#dt_hp)
#     - [Step 9.3 | Decision Tree Model Evaluation](#dt_eval)
# * [Step 10 | KNN Model Building](#knn)
#     - [Step 10.1 | KNN Base Model Definition](#knn_base)
#     - [Step 10.2 | KNN Hyperparameter Tuning](#knn_hp)
#     - [Step 10.3 | KNN Model Evaluation](#knn_eval)
# * [Step 11 | Feature Importance Visualization](#feature)
# * [Step 12 | Conclusion](#conclusion)
# * [Step 13 | Prediction](#pred)

# %% [markdown]
# <a id="import"></a>
# # <p style="background-color:#338aff; font-family:calibri; color:white; font-size:150%; text-align:center; border-radius:15px 50px;">Step 1 | Import Libraries</p>
#
# ⬆️ [Table of Contents](#contents_tabel)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.ticker as mtick
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier , GradientBoostingClassifier, AdaBoostClassifier
from xgboost import XGBClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from imblearn.over_sampling import SMOTE

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report , roc_curve, roc_auc_score

# %% [markdown]
# <a id="read"></a>
# # <p style="background-color:#338aff ; font-family:calibri; color:white; font-size:150%; text-align:center; border-radius:15px 50px;">Step 2 | LOAD DATASET</p>
#
# ⬆️ [Table of Contents](#contents_tabel)

# %%
data = pd.read_csv("C:/Users/HP/Downloads/water_potability.csv")

# %%
data.head()
# Out:
#          ph    Hardness       Solids  Chloramines     Sulfate  Conductivity  \
# 0       NaN  204.890456  20791.31898     7.300212  368.516441    564.308654
# 1  3.716080  129.422921  18630.05786     6.635246         NaN    592.885359
# 2  8.099124  224.236259  19909.54173     9.275884         NaN    418.606213
# 3  8.316766  214.373394  22018.41744     8.059332  356.886136    363.266516
# 4  9.092223  181.101509  17978.98634     6.546600  310.135738    398.410813
#
#    Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       10.379783        86.990970   2.963135           0
# 1       15.180013        56.329076   4.500656           0
# 2       16.868637        66.420093   3.055934           0
# 3       18.436525       100.341674   4.628771           0
# 4       11.558279        31.997993   4.075075           0

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; font-size:115%; text-align:left ;background-color:#e2e5e9; color :black">
# <center><h2><font>Dataset Description:</font></h2></center>
#
# | __Column Name__ | __Description__ |
# |     :---      |       :---      |
# | __ph__ | pH measures the acidity or alkalinity of water. It influences corrosion and the effectiveness of disinfection.|
# | __Hardness__ | Represents the concentration of calcium and magnesium in water. High hardness can lead to scale formation. |
# | __Solids__ | Total dissolved solids (TDS) indicate the amount of minerals, salts, and metals dissolved in water. |
# | __Chloramines__ | Chloramines are a type of disinfectant used in water treatment to kill bacteria and other pathogens. |
# | __Sulfate__ | Naturally occurring in water, sulfate contributes to taste and may have effects on plumbing. |
# | __Conductivity__ | Reflects water’s ion concentration, giving insight into its mineral and chemical content.|
# | __Organic_carbon__ | Total organic carbon is a measure of the organic molecules present, often from natural decay or pollution. |
# | __Trihalomethanes__ | Chemical compounds formed when chlorine used in water treatment reacts with organic matter. |
# | __Turbidity__ | Refers to the cloudiness or haziness of water, usually caused by suspended particles.) |
# | __Potability__ | Indicates whether water is safe for human consumption, with 1 for potable and 0 for non-potable.|

# %%
data.shape
# Out:
# (3276, 10)

# %% [markdown]
# <a id="overview"></a>
# # <p style="background-color:#338aff; font-family:calibri; color:white; font-size:150%; text-align:center; border-radius:15px 50px;">Step 3 | Dataset Overview</p>
#
# ⬆️ [Table of Contents](#contents_tabel)

# %% [markdown]
# _____
# <a id="basic"></a>
# # <b><span style='color:#338aff'>Step 3.1 |</span><span style='color:#338aff'> Dataset Basic Information</span></b>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3276 entries, 0 to 3275
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ph               2785 non-null   float64
#  1   Hardness         3276 non-null   float64
#  2   Solids           3276 non-null   float64
#  3   Chloramines      3276 non-null   float64
#  4   Sulfate          2495 non-null   float64
#  5   Conductivity     3276 non-null   float64
#  6   Organic_carbon   3276 non-null   float64
#  7   Trihalomethanes  3114 non-null   float64
#  8   Turbidity        3276 non-null   float64
#  9   Potability       3276 non-null   int64
# dtypes: float64(9), int64(1)
# memory usage: 256.1 KB

# %% [markdown]
# _____
#
# <a id="dtypes"></a>
# # <b><span style='color:#338aff'>Step 3.2 |</span><span style='color:#338aff'>Display the Datatypes of each column</span></b>

# %%
data.dtypes
# Out:
# ph                 float64
# Hardness           float64
# Solids             float64
# Chloramines        float64
# Sulfate            float64
# Conductivity       float64
# Organic_carbon     float64
# Trihalomethanes    float64
# Turbidity          float64
# Potability           int64
# dtype: object

# %% [markdown]
# ______
# <a id="num_statistics"></a>
# # <b><span style='color:#338aff'>Step 3.3 |</span><span style='color:#338aff'> Summury statisc for numerical veriables</span></b>

# %%
data.describe().T
# Out:
#                   count          mean          std         min           25%  \
# ph               2785.0      7.080795     1.594320    0.000000      6.093092
# Hardness         3276.0    196.369496    32.879761   47.432000    176.850538
# Solids           3276.0  22014.092526  8768.570828  320.942611  15666.690300
# Chloramines      3276.0      7.122277     1.583085    0.352000      6.127421
# Sulfate          2495.0    333.775777    41.416840  129.000000    307.699498
# Conductivity     3276.0    426.205111    80.824064  181.483754    365.734414
# Organic_carbon   3276.0     14.284970     3.308162    2.200000     12.065801
# Trihalomethanes  3114.0     66.396293    16.175008    0.738000     55.844536
# Turbidity        3276.0      3.966786     0.780382    1.450000      3.439711
# Potability       3276.0      0.390110     0.487849    0.000000      0.000000
#
#                           50%           75%           max
# ph                   7.036752      8.062066     14.000000
# ...

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; font-size:115%; text-align:left ;background-color:#e2e5e9; color :black">
#
# <h3 align="left"><font >Numerical Features:</font></h3>
#
# | __Column Name__ | __Description__ |
# |     :---      |       :---      |
# | __ph__ |The mean pH value is approximately 7.08, with a standard deviation of 1.41, indicating moderate variability in acidity/alkalinity. The minimum pH value is 0, and the maximum is 14. |
# | __Hardness__ | The average hardness of the water is around 196.87 mg/L, with a standard deviation of 32.88 mg/L. Hardness values range from 47.32 mg/L to 323.32 mg/L. |
# | __Solids__ | The mean total dissolved solids (TDS) in the water are about 21895.69 mg/L, with a high standard deviation of 10545.75 mg/L, reflecting a wide range of dissolved material. TDS values range from 320.94 mg/L to 61227.20 mg/L. |
# | __Chloramines__ | The average chloramine concentration is 7.13 mg/L, with a standard deviation of 1.59 mg/L, ranging from 0.35 mg/L to 13.12 mg/L.
# | __Sulfate__  | The mean sulfate concentration is approximately 333.07 mg/L, with a standard deviation of 86.29 mg/L, and values range from 129.00 mg/L to 757.00 mg/L. |
# | __Conductivity__ | The mean conductivity is around 426.21 μS/cm, with a standard deviation of 100.23 μS/cm. Conductivity values range from 181.44 μS/cm to 753.34 μS/cm. |
# | __Organic_carbon__ |   The average organic carbon content is about 14.28 ppm, with a standard deviation of 3.32 ppm, and values range from 2.20 ppm to 28.30 ppm. |
# | __Trihalomethanes__  | The average concentration of trihalomethanes is 66.40 ppm, with a standard deviation of 16.74 ppm, ranging from 0.74 ppm to 124.00 ppm.
# | __Turbidity__ | The mean turbidity of the water is 3.99 NTU, with a standard deviation of 1.04 NTU. Turbidity ranges from 1.45 NTU to 6.73 NTU. |

# %% [markdown]
# <a id="eda"></a>
# # <p style="background-color:#338aff; font-family:calibri; color:white; font-size:150%; text-align:center; border-radius:15px 50px;">Step 4 |Check Distributions (EDA)</p>
#
# ⬆️ [Table of Contents](#contents_tabel)

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; font-size:115%; text-align:left ;background-color:#e2e5e9; color :black">
#
# For our __Exploratory Data Analysis (EDA)__, we'll take it in two main steps:
#
# __1. Univariate Analysis__: In this step, we will examine each feature individually to understand its distribution, spread, and range.
# Examples: Analyzing the distribution of a single feature (like pH) using histograms, box plots, or statistical summaries.
#
# __2. Bivariate Analysis__: In this step, we will explore the relationships between two variables, focusing primarily on how each feature relates to
# the target variable (Potability). This helps us understand the influence and importance of each feature in predicting the outcome.
# Examples: Correlation analysis between two variables (e.g., pH and Potability), scatter plots, and heatmaps to visualize relationships.
#
#   With these two steps, we aim to gain insights into the individual characteristics of the data and also how each feature relates to our main goal:
#    __predicting the target variable__.

# %% [markdown]
# _____
#
# <a id="univariate"></a>
# # <b><span style='color:#338aff'>Step 4.1 |</span><span style='color:#338aff'> Univariate Analysis</span></b>

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; font-size:115%; text-align:left ;background-color:#e2e5e9; color :black">
#
# We undertake __univariate analysis__ on the dataset's features, based on their datatype:
#
# * For __continuous data__: We employ histograms to gain insight into the distribution of each feature. This allows us to understand
# the central tendency, spread, and shape of the dataset's distribution.
#
#
# * For __categorical data__: We employ a pie chart to visualize the proportions of water samples classified as "Potable (1)" and "Not Potable (0)".
# This circular representation provides an intuitive understanding of the distribution of potability classes, allowing for a quick assessment of the
# relative frequency of each category.
#
# By employing these visualization techniques, we're better positioned to understand the individual characteristics of each feature in the dataset.

# %% [markdown]
# ____
#
# <a id="num_uni"></a>
# ### <b><span style='color:#338aff'>Step 4.1.1 |</span><span style='color:#338aff'> Check the distribution of continuous variables</span></b>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid")

# Create a figure for the continuous variable distribution
plt.figure(figsize=(15, 20))  # Adjust the figure size if needed
for i, col in enumerate(data.columns):
    if col != 'Potability':
        ax = plt.subplot(5, 2, i + 1)  # Adjust the grid size as necessary
        sns.histplot(data[col], kde=True, color='blue')
        plt.title(f'Distribution of {col}', fontsize=14)
        plt.xlabel(col)
        plt.ylabel('Density')
        
        # Set the background color for the grid
        ax.set_facecolor('#f0f0fa')  # Change to your desired color

# Adjust layout
plt.tight_layout()
# # Save the figure before displaying it
# plt.savefig('chart_name.png', dpi=300, bbox_inches='tight', pad_inches=0)

plt.show()

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color:#e2e5e9; font-size:115%; text-align:left ;color :black">
# <h2 align="left"><font >Inferences:</font></h2>
#
# __`pH`__: The distribution is nearly normal, with values mostly centered around 7-8. The mean pH is approximately 7.08, with some outliers on both acidic and basic sides, indicating potential water quality concerns at extremes.
#
# __`Hardness`__: Water hardness is moderately right-skewed, with most values between 175-225 mg/L. The mean hardness is around 196.37 mg/L, showing moderate water hardness, with some samples exceeding typical levels.
#
# __`Total Dissolved Solids (TDS)`__: The distribution is heavily skewed to the right. Most values are concentrated around 15,000-30,000 mg/L, with the mean at approximately 22,014 mg/L. Some extreme values indicate poor water quality in certain areas.
#
# __`Chloramines`__: Chloramines show a normal distribution, with most values concentrated between 6-8 mg/L. The mean is 7.12 mg/L, reflecting effective disinfection, though higher concentrations are observed in some cases.
#
# __`Sulfate`__: The distribution is approximately normal, with most sulfate levels ranging between 300-400 mg/L. The mean is 333.78 mg/L, indicating that sulfate concentrations are generally within acceptable limits, though there is some variability.
#
# __`Conductivity`__: Conductivity is right-skewed, with most values between 350-450 μS/cm. The mean conductivity is 426.21 μS/cm, with a few higher values suggesting higher levels of dissolved ions.
#
# __`Organic Carbon`__: Organic carbon shows a relatively normal distribution, with values concentrated around 10-18 ppm. The mean is 14.28 ppm, indicating typical organic content levels in water, though some samples have elevated organic matter.
#
# __`Trihalomethanes`__: This feature is slightly right-skewed, with most values between 50-80 ppm. The mean concentration is 66.40 ppm, with some higher outliers, potentially indicating concerns over disinfection byproducts.
#
# __`Turbidity`__: Turbidity is slightly right-skewed, with most values between 3-5 NTU. The mean turbidity is 3.97 NTU, reflecting relatively clear water in most cases, though some samples show higher cloudiness.

# %% [markdown]
# _____
#
# <a id="cat_uni"></a>
# ### <b><span style='color:#338aff'>Step 4.1.2 |</span><span style='color:#338aff'> Check the distribution of Categorical  variabless</span></b>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set the aesthetic style of the plots
sns.set_style("whitegrid")

# Create a separate figure for the categorical variable 'Potability'
plt.figure(figsize=(6, 4), dpi=150)  # Increased resolution with dpi=150
potability_counts = data['Potability'].value_counts()

# Use a refined color palette from Seaborn
colors = sns.color_palette("Set2", 2)  # Use a more visually appealing palette
plt.pie(potability_counts, labels=['Not Potable (0)', 'Potable (1)'], 
        colors=colors, autopct='%1.1f%%', startangle=90, 
        wedgeprops={'edgecolor': 'black'}, textprops={'fontsize': 9})

# Set title with enhanced styling
plt.title('Proportion of Potability Categorical Classes', fontsize=10, fontweight='bold')
plt.axis('equal')
plt.show()

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color: #e2e5e9; font-size:115%; text-align:left ;color :black">
# <h2 align="left"><font>Inferences:</font></h2>
#
# __`Potable (1)`__:
# Proportion: Approximately 39.0% of the samples are classified as Potable.
# Interpretation: This indicates that a significant portion of the water samples meets the quality standards for safe drinking, suggesting effective treatment and compliance with safety guidelines.
#
# __`Not Potable (0)`__:
# Proportion: Approximately 61.0% of the samples are classified as Not Potable.
# Interpretation: A considerable number of samples do not meet the quality standards for drinking water, highlighting potential concerns regarding water safety and the need for treatment or intervention.
#
# Around 61.7% of the water samples are Not Potable.
# Only about 38.3% of the samples are classified as Potable.
# This suggests that Not Potable water samples dominate the dataset, indicating that more water samples fail to meet the standards for potability, which aligns with the skewness seen in some continuous variables like TDS and Hardness.

# %% [markdown]
# ______
# <a id="bivariate"></a>
# # <b><span style='color:#338aff'>Step 4.2 |</span><span style='color:#338aff'> Bivariate Analysis</span></b>

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; font-size:115%; text-align:left ;background-color:#e2e5e9; color :black">
#
# For our __Bivariate analysis__ on the dataset's features with respect to the target variable:
#
# * For __continuous data__: We will use box plots to visualize the distribution of numeric features across potability classes, highlighting the median and any potential outliers.
#
# Through these visualization techniques, we are going to gain a deeper understanding of the relationship between individual features and the target, revealing potential predictors for heart disease.

# %% [markdown]
# _____
# <a id="num_target"></a>
# ### <b><span style='color:#338aff'>Step 4.2.1 |</span><span style='color:#338aff'>Check the distribution with target variable (using boxplot)</span></b>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming 'data' is your DataFrame
num_features = len(data.columns) - 1  # Exclude the target variable 'Potability'
fig, axes = plt.subplots(nrows=(num_features + 1) // 2, ncols=2, figsize=(15, 20))
axes = axes.flatten()
features = data.columns[:-1]  # Exclude the target variable 'Potability'

# Define a color palette
palette = sns.color_palette("Set2", n_colors=2)

# Create box plots for each feature
for i, feature in enumerate(features):
    sns.boxplot(x='Potability', y=feature, data=data, ax=axes[i], hue='Potability', palette=palette, dodge=False)
    axes[i].set_title(f'Box Plot of {feature} by Potability', fontsize=14)
    axes[i].set_xlabel('Potability')
    axes[i].set_ylabel(feature)

    # Set x-tick labels directly
    axes[i].set_xticks([0, 1])  # Ensure there are ticks at the correct positions
    axes[i].set_xticklabels(['Non-Potable (0)', 'Potable (1)'])

# Hide any unused subplots (if the number of features is odd)
for j in range(i + 1, len(axes)):
    axes[j].axis('off')

plt.tight_layout()
# Save the figure as an image file
# plt.savefig('box_plots_by_potability.png', dpi=300)  # Adjust the dpi as needed
plt.show()

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; font-size:115%; text-align:left; background-color:#e2e5e9; color:black">
#     <h2>Box Plot Summary</h2>
#
# __`pH`__: Non-potable water shows more pH variability, indicating extreme acidity or alkalinity impacts potability.
#
# __`Hardness`__: Higher hardness is generally associated with non-potable water, though ranges overlap.
#
# __`TDS (Solids)`__: Non-potable water exhibits higher total dissolved solids, indicating potential contaminants.
#
# __`Chloramines`__: Higher chloramine levels are more common in non-potable water, suggesting disinfection byproducts.
#
# __`Sulfate`__: Sulfate levels are similar across both categories but slightly more variable in non-potable water.
#
# __`Conductivity`__: Non-potable water shows higher conductivity, signaling greater dissolved ion concentration.
#
# __`Organic Carbon`__: Non-potable water has higher organic carbon, hinting at decaying organic material.
#
# __`Trihalomethanes`__: Non-potable water generally has higher trihalomethane concentrations, possibly due to contamination.
#
# __`Turbidity`__: Non-potable water shows higher turbidity, indicating poorer clarity and water quality.

# %% [markdown]
# ____
#
# <a id="corr"></a>
# ### <b><span style='color:#338aff'>Step 4.2.2 |</span><span style='color:#338aff'>Check Correlation Matrix with Target Variable (Using Heatmap)</span></b>

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; font-size:115%; text-align:left ;background-color:#e2e5e9; color :black">
#
# * For __Correlation Matrix__ :  In this analysis, we calculated the correlation matrix for the numerical features in our water quality dataset. The correlation matrix provides insight into the relationships between the various continuous variables, displaying how they correlate with each other.
#
# * The resulting correlation matrix reveals the strength and direction of relationships between each feature and the potability of water. Positive correlation coefficients indicate that as a feature increases, the likelihood of the water being potable also increases, while negative coefficients suggest an inverse relationship.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Calculate the correlation matrix
correlation_matrix = data.corr()

# Display the correlation matrix using a heatmap with the coolwarm color palette
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Matrix of Water Quality Features', fontsize=16)

# Save the heatmap as an image file
plt.savefig('correlation_matrix_heatmap.png', dpi=300)  # Adjust the filename and dpi as needed
plt.show()

# %% [markdown]
# <table style="border-collapse: collapse; width: 100%; text-align: left; color :black">
#   <tr style="background-color: #e2e5e9; border: 1px solid black;">
#     <th style="padding: 10px; border: 1px solid black;">Feature</th>
#     <th style="padding: 10px; border: 1px solid black;">Strongest Positive Correlation</th>
#     <th style="padding: 10px; border: 1px solid black;">Correlation Value</th>
#     <th style="padding: 10px; border: 1px solid black;">Strongest Negative Correlation</th>
#     <th style="padding: 10px; border: 1px solid black;">Correlation Value</th>
#   </tr>
#   <tr style="border: 1px solid black;background-color: #e2e5e9">
#     <td style="padding: 10px; border: 1px solid black;">pH</td>
#     <td style="padding: 10px; border: 1px solid black;">Hardness</td>
#     <td style="padding: 10px; border: 1px solid black;">0.08</td>
#     <td style="padding: 10px; border: 1px solid black;">Solids</td>
#     <td style="padding: 10px; border: 1px solid black;">-0.09</td>
#   </tr>
#   <tr style="border: 1px solid black;background-color: #e2e5e9">
#     <td style="padding: 10px; border: 1px solid black;">Hardness</td>
#     <td style="padding: 10px; border: 1px solid black;">pH</td>
#     <td style="padding: 10px; border: 1px solid black;">0.08</td>
#     <td style="padding: 10px; border: 1px solid black;">Sulfate</td>
#     <td style="padding: 10px; border: 1px solid black;">-0.11</td>
#   </tr>
#   <tr style="border: 1px solid black;background-color: #e2e5e9">
#     <td style="padding: 10px; border: 1px solid black;">Solids</td>
#     <td style="padding: 10px; border: 1px solid black;">Potability</td>
#     <td style="padding: 10px; border: 1px solid black;">0.03</td>
#     <td style="padding: 10px; border: 1px solid black;">Sulfate</td>
#     <td style="padding: 10px; border: 1px solid black;">-0.17</td>
#   </tr>
#   <tr style="border: 1px solid black;background-color: #e2e5e9">
#     <td style="padding: 10px; border: 1px solid black;">Chloramines</td>
#     <td style="padding: 10px; border: 1px solid black;">Potability</td>
#     <td style="padding: 10px; border: 1px solid black;">0.02</td>
#     <td style="padding: 10px; border: 1px solid black;">Solids</td>
#     <td style="padding: 10px; border: 1px solid black;">-0.07</td>
#   </tr>
#   <tr style="border: 1px solid black;background-color: #e2e5e9">
#     <td style="padding: 10px; border: 1px solid black;">Sulfate</td>
#     <td style="padding: 10px; border: 1px solid black;">pH</td>
#     <td style="padding: 10px; border: 1px solid black;">0.02</td>
#     <td style="padding: 10px; border: 1px solid black;">Solids</td>
#     <td style="padding: 10px; border: 1px solid black;">-0.17</td>
#   </tr>
#   <tr style="border: 1px solid black;background-color: #e2e5e9">
#     <td style="padding: 10px; border: 1px solid black;">Conductivity</td>
#     <td style="padding: 10px; border: 1px solid black;">Potability</td>
#     <td style="padding: 10px; border: 1px solid black;">0.02</td>
#     <td style="padding: 10px; border: 1px solid black;">Turbidity</td>
#     <td style="padding: 10px; border: 1px solid black;">-0.02</td>
#   </tr>
#   <tr style="border: 1px solid black;background-color: #e2e5e9">
#     <td style="padding: 10px; border: 1px solid black;">Organic Carbon</td>
#     <td style="padding: 10px; border: 1px solid black;">pH</td>
#     <td style="padding: 10px; border: 1px solid black;">0.04</td>
#     <td style="padding: 10px; border: 1px solid black;">Potability</td>
#     <td style="padding: 10px; border: 1px solid black;">-0.03</td>
#   </tr>
#   <tr style="border: 1px solid black;background-color: #e2e5e9">
#     <td style="padding: 10px; border: 1px solid black;">Trihalomethanes</td>
#     <td style="padding: 10px; border: 1px solid black;">Chloramines</td>
#     <td style="padding: 10px; border: 1px solid black;">0.02</td>
#     <td style="padding: 10px; border: 1px solid black;">pH</td>
#     <td style="padding: 10px; border: 1px solid black;">-0.01</td>
#   </tr>
#   <tr style="border: 1px solid black;background-color: #e2e5e9">
#     <td style="padding: 10px; border: 1px solid black;">Turbidity</td>
#     <td style="padding: 10px; border: 1px solid black;">Solids</td>
#     <td style="padding: 10px; border: 1px solid black;">0.02</td>
#     <td style="padding: 10px; border: 1px solid black;">pH</td>
#     <td style="padding: 10px; border: 1px solid black;">-0.04</td>
#   </tr>
#   <tr style="border: 1px solid black;background-color: #e2e5e9">
#     <td style="padding: 10px; border: 1px solid black;">Potability</td>
#     <td style="padding: 10px; border: 1px solid black;">Solids</td>
#     <td style="padding: 10px; border: 1px solid black;">0.03</td>
#     <td style="padding: 10px; border: 1px solid black;">Hardness</td>
#     <td style="padding: 10px; border: 1px solid black;">-0.01</td>
#   </tr>
# </table>

# %% [markdown]
# <a id="preprocessing"></a>
# # <p style="background-color:#338aff; font-family:calibri; color:white; font-size:150%; text-align:center; border-radius:15px 50px;">Step 5 | Data Preprocessing</p>
# ⬆️ [Table of Contents](#contents_tabel)

# %% [markdown]
# ____
# <a id="missing"></a>
# # <b><span style='color:#338aff'>Step 5.1 |</span><span style='color:#338aff'> Check missing values</span></b>

# %%
# Check for missing values
print("\nMissing values in each column:")
print(data.isnull().sum())
# Out:
# Missing values in each column:
# ph                 491
# Hardness             0
# Solids               0
# Chloramines          0
# Sulfate            781
# Conductivity         0
# Organic_carbon       0
# Trihalomethanes    162
# Turbidity            0
# Potability           0
# dtype: int64

# %%
# Handle missing values using median
data.fillna(data.median(), inplace=True)

# %%
data.isnull().sum()
# Out:
# ph                 0
# Hardness           0
# Solids             0
# Chloramines        0
# Sulfate            0
# Conductivity       0
# Organic_carbon     0
# Trihalomethanes    0
# Turbidity          0
# Potability         0
# dtype: int64

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; font-size:115%; text-align: center ;background-color:#e2e5e9; color :black">
# <h3 align="left"><font>Conclusion on Handling Missing Values with Median Imputation : </font></h3>
#
# Filling missing values with the median is beneficial, especially in datasets with outliers, as it reduces their impact and preserves the distribution.
# The median ensures that the imputed data is representative of the majority, enhancing the integrity of the dataset. This approach improves machine learning model performance by providing complete data, leading to more accurate insights into water quality features and strengthening the robustness of the analysis.

# %% [markdown]
# ____
# <a id="outlier"></a>
# # <b><span style='color:#338aff'>Step 5.2 |</span><span style='color:#338aff'> Outlier Tretment</span></b>

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; font-size:115%; text-align: center ;background-color:#e2e5e9; color :black">
#
#   I am going to check for outliers using the __`IQR`__ method for the continuous features:
#   The __`IQR`__ method is widely used for detecting outliers because it is robust, simple to implement, and effective for various data distributions without being overly     sensitive to extreme values.

# %%
Q1 = data.quantile(0.25)
Q3 = data.quantile(0.75)
IQR = Q3 - Q1
outliers_count_specified = ((data < (Q1 - 1.5 * IQR)) | (data > (Q3 + 1.5 * IQR))).sum()

outliers_count_specified
# Out:
# ph                 142
# Hardness            83
# Solids              47
# Chloramines         61
# Sulfate            264
# Conductivity        11
# Organic_carbon      25
# Trihalomethanes     54
# Turbidity           19
# Potability           0
# dtype: int64

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; font-size:115%; text-align:left; background-color:#e2e5e9; color :black" >
#
# Upon identifying outliers for the specified continuous features, we found the following:
#
# * __`ph`__: 142 outliers
# * __`Hardness`__: 83 outliers
# * __`Solids   `__: 47 outlier
# * __`Chloramines`__: 61 outliers
# * __`Sulfate`__: 264 outliers
# * __`Conductivity`__: 11 outliers
# * __`Organic_carbon`__: 25 outliers
# * __`Trihalomethanes`__: 54 outliers
# * __`Turbidity`__: 19 outliers

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; font-size:120%; text-align:left;background-color:#e2e5e9; color :black">
#
#   <h4 align="left" style="font-weight:bold;">Conclusion:</h4>
#
#   <ul>
#     <li>Outliers play a critical role in our water potability dataset, especially for the machine learning algorithms we intend to employ, such as KNN, SVM, Decision Tree, Random Forest, and XGBoost.</li>
#     <li>Removing these outliers may lead to a loss of valuable information and negatively impact the model's predictive performance.</li>
#     <li>To address this challenge, we will explore alternative techniques to mitigate the influence of outliers while preserving them in the dataset.</li>
#     <li>This strategy aims to enhance the robustness and accuracy of our models, ensuring that we make informed predictions without sacrificing important data insights.</li>
#   </ul>
#
# </div>

# %% [markdown]
# ____
# <a id="eng"></a>
# # <b><span style='color:#338aff'>Step 5.3 | Feature engineering</span><span style='color:#bb8aff'> </span></b>

# %%
# Feature engineering
data['pH_Hardness'] = data['ph'] * data['Hardness']

# %%
data.head()
# Out:
#          ph    Hardness       Solids  Chloramines     Sulfate  Conductivity  \
# 0  7.036752  204.890456  20791.31898     7.300212  368.516441    564.308654
# 1  3.716080  129.422921  18630.05786     6.635246  333.073546    592.885359
# 2  8.099124  224.236259  19909.54173     9.275884  333.073546    418.606213
# 3  8.316766  214.373394  22018.41744     8.059332  356.886136    363.266516
# 4  9.092223  181.101509  17978.98634     6.546600  310.135738    398.410813
#
#    Organic_carbon  Trihalomethanes  Turbidity  Potability  pH_Hardness
# 0       10.379783        86.990970   2.963135           0  1441.763344
# 1       15.180013        56.329076   4.500656           0   480.945936
# 2       16.868637        66.420093   3.055934           0  1816.117313
# 3       18.436525       100.341674   4.628771           0  1782.893330
# 4       11.558279        31.997993   4.075075           0  1646.615390

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; font-size:120%; text-align:left ;background-color:#e2e5e9; color :black">
#
#   <h4 style="font-weight:bold;">Conclusion:</h4>
#
# Given the high positive correlation between __`pH`__ and __`Hardness`__, we will create a new feature by multiplying these two variables. This approach aims to enhance the model's predictive power by capturing the combined effect of these features on water potability. By integrating this interaction term into our dataset, we can potentially improve the model's performance while retaining the valuable information provided by both features.

# %% [markdown]
# ____
# <a id="scale"></a>
# # <b><span style='color:#338aff'>Step 5.4 |</span><span style='color:#338aff'> Scale Features </span></b>

# %%
# Separate features (X) and target (y)
X = data.drop('Potability', axis=1)
y = data['Potability']

# Initialize StandardScaler
scaler = StandardScaler()
# Fit and transform the features
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; font-size:115%; text-align:left; background-color:#e2e5e9; color :black">
#
#   <h4 style="font-weight:bold;">Conclusion on Using StandardScaler:</h4>
#
#   <ul>
#     <li>The use of <strong>StandardScaler</strong> is essential for preprocessing our dataset, particularly when applying machine learning algorithms.</li>
#     <li>StandardScaler transforms the features to have a mean of 0 and a standard deviation of 1, which provides several benefits:</li>
#     <ul>
#       <li><strong>Normalization of Features:</strong> Ensures that all features contribute equally to the distance calculations in algorithms like KNN and SVM, preventing bias towards features with larger ranges.</li>
#       <li><strong>Improved Convergence:</strong> Many optimization algorithms converge faster when the features are standardized, leading to quicker model training.</li>
#       <li><strong>Enhanced Model Performance:</strong> Algorithms that rely on distance measures perform better with standardized data, improving accuracy and predictive power.</li>
#       <li><strong>Consistency:</strong> Provides a consistent scale across all features, making it easier to interpret feature importance and the impact of each variable on the model.</li>
#     </ul>
#     <li>Overall, applying StandardScaler enhances the reliability and effectiveness of our machine learning models, supporting more robust predictions regarding water potability.</li>
#   </ul>
#
# </div>

# %% [markdown]
# ____
# <a id="imbalance"></a>
# # <b><span style='color:#338aff'>Step 5.5 |</span><span style='color:#338aff'> Handling Class Imbalance:
# </span></b>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set the aesthetic style of the plots
sns.set_style("whitegrid")
class_counts = data['Potability'].value_counts()

# Define refined colors from Seaborn's Set2 palette
colors = sns.color_palette("Set2", 2)  # Soft pastel colors
plt.figure(figsize=(5,4), dpi=150)

# Create a bar chart with refined colors and black edges
plt.bar(class_counts.index, class_counts.values, color=colors, edgecolor='black', linewidth=1.5)
plt.xlabel('Potability', fontsize=9)
plt.ylabel('Number of Samples', fontsize=9)
plt.title('Class Distribution Before Balancing', fontsize=9, fontweight='bold')
plt.text(0, class_counts[0] + 20, str(class_counts[0]), ha='center', fontsize=9, fontweight='bold')
plt.text(1, class_counts[1] + 20, str(class_counts[1]), ha='center', fontsize=9, fontweight='bold')

# Set custom x-tick labels
plt.xticks([0, 1], ['Not Potable (0)', 'Potable (1)'], fontsize=9)
plt.show()

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; font-size:115%; text-align:left; background-color:#e2e5e9; color:black">
#
#   <h4>Conclusion on Addressing Class Imbalance:</h4>
#
#   <ul>
#     <li>The analysis of the dataset reveals a significant class imbalance, with fewer samples categorized as <strong>Potable</strong> (1) compared to <strong>Not Potable</strong> (0).</li>
#     <li>This imbalance can lead to biased predictions from machine learning models, favoring the majority class, which may compromise model effectiveness.</li>
#     <li>To combat this issue, we will utilize the <strong>Synthetic Minority Over-sampling Technique (SMOTE)</strong>, which offers several advantages:</li>
#     <ul>
#       <li><strong>Equal Representation:</strong> SMOTE generates synthetic samples for the minority class, ensuring both classes are equally represented in the dataset.</li>
#       <li><strong>Improved Learning:</strong> By balancing the classes, SMOTE allows models to learn more effectively from both classes, enhancing their ability to make accurate predictions.</li>
#       <li><strong>Reduction of Bias:</strong> Addressing class imbalance helps mitigate the bias that can occur in models trained on imbalanced datasets, leading to fairer predictions.</li>
#       <li><strong>Enhanced Model Performance:</strong> Balanced classes often result in improved metrics, such as accuracy, precision, and recall, providing a more reliable assessment of model performance.</li>
#     </ul>
#     <li>Overall, employing SMOTE is crucial for improving the robustness and reliability of our machine learning models, ultimately leading to better predictions of water potability.</li>
#   </ul>
#
# </div>

# %%
# Apply SMOTE to balance the dataset
smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X_scaled, y)

#  Print the class distribution after SMOTE
print("Class distribution after SMOTE:")
print(y_resampled.value_counts())
# Out:
# Class distribution after SMOTE:
# Potability
# 0    1998
# 1    1998
# Name: count, dtype: int64

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; font-size:120%; text-align:left ;background-color:#e2e5e9; color :black">
#
# <h4 align="left"><font>Conclusion:</font></h4>
#
# Applying __`SMOTE`__ (Synthetic Minority Over-sampling Technique) is useful because it effectively balances class distributions in imbalanced datasets, ensuring that both classes (e.g., Potable and Not Potable) are equally represented. This balance enhances model training by providing the algorithm with enough data to learn from both classes, reducing bias toward the majority class and improving overall prediction accuracy. As a result, models trained on SMOTE-processed data are better equipped to generalize to unseen instances, making them more reliable in real-world applications.

# %%
import matplotlib.pyplot as plt

# Assuming y_resampled is your balanced target variable
class_counts = y_resampled.value_counts()

# Create a pie chart with enhanced styling
plt.figure(figsize=(5, 4), dpi=150)
colors = sns.color_palette("Set2", 2)  # Refined pastel colors

# Create an "exploded" pie chart with shadow for a more unique look
explode = (0.05, 0)  # Slightly explode the first slice (Non-Potable)
plt.pie(class_counts, labels=['Non-Potable', 'Potable'], autopct='%1.1f%%', startangle=90, 
        colors=colors, explode=explode, shadow=True, wedgeprops={'edgecolor': 'black'})
plt.title('Class Distribution After SMOTE', fontsize=10, fontweight='bold')
plt.axis('equal')
plt.show()

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; font-size:120%; text-align:left ;background-color:#e2e5e9; color :black">
#
# <h4 align="left"><font>Conclusion on Class Distribution After SMOTE :</font></h4>
#
# The pie chart illustrates the class distribution of the target variable after applying __`SMOTE`__  for balancing. The slight explosion of the Non-Potable slice emphasizes its importance, highlighting that the distribution is now more equitable between the Potable and Non-Potable classes. This balanced representation enhances the model's ability to learn from both classes effectively, thereby improving its predictive accuracy and robustness in classifying water potability.
# </div>

# %%
# Split the data into training and testing sets

X_train, X_test, y_train, y_test = train_test_split(X_resampled,y_resampled, test_size=0.2, random_state=42)

# %% [markdown]
# <a id="rf"></a>
# # <p style="background-color:#338aff; font-family:calibri; color:white; font-size:150%; text-align:center; border-radius:15px 50px;">Step 6 |Random Forest Model Building</p>
#
# ⬆️ [Table of Contents](#contents_tabel)

# %% [markdown]
# ____
# <a id="rf_base"></a>
# # <b><span style='color:#338aff'>Step 6.1 |</span><span style='color:#338aff'> Random Forest Model Definition</span></b>

# %%
# Initialize the Random Forest classifier
rf_classifier = RandomForestClassifier(random_state=42)
rf_classifier.fit(X_train, y_train)
y_pred = rf_classifier.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy Random forest Base model:", accuracy)
# Out:
# Accuracy Random forest Base model: 0.735

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; font-size:120%; text-align:left ;background-color:#e2e5e9; color :black">
#
# The base __`Random Forest`__ model achieved an accuracy of **0.735%**, demonstrating its initial effectiveness in predicting water quality.

# %% [markdown]
# ____
# <a id="rf_hp"></a>
# # <b><span style='color:#338aff'>Step 6.2 |</span><span style='color:#338aff'> Random Forest Hyperparameter Tuning</span></b>

# %%
# Define a more focused parameter grid for Random Search
param_grid = {
      'n_estimators': [200,300],  # Fewer options for less time
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5],
    'min_samples_leaf': [1, 2],
    'max_features': ['sqrt'],
    'bootstrap': [True, False]             # Keep bootstrap as True
}

# Initialize the Random Search with cross-validation
random_search = RandomizedSearchCV(estimator=rf_classifier,
                                   param_distributions=param_grid,
                                   n_iter=20,              # Fewer iterations
                                   cv=3,                   # Reduced cross-validation folds
                                   scoring='accuracy',
                                   random_state=42,
                                   n_jobs=-1)

# Fit the model to find the best hyperparameters
random_search.fit(X_train, y_train)

best_params = random_search.best_params_
print("Best Hyperparameters:", best_params)

best_rf = RandomForestClassifier(**best_params, random_state=42)
best_rf.fit(X_train, y_train)

# Evaluate the best model on the test set
y_pred_best = best_rf.predict(X_test)
accuracy_best = accuracy_score(y_test, y_pred_best)
print("Accuracy After Hyperparameter tuning:", accuracy_best)
# Out:
# Best Hyperparameters: {'n_estimators': 300, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'max_depth': None, 'bootstrap': False}
# Accuracy After Hyperparameter tuning: 0.74

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color: #e2e5e9; font-size:120%; text-align:left ;color :black">
#
# <h2 align="left"><font>Inference:</font></h2>
#
# After hyperparameter tuning, the __`Random Forest`__ model achieved an accuracy of **0.74**, showcasing significant improvement over the baseline. This underscores the pivotal role of tuning parameters such as `n_estimators`, `min_samples_split`, `min_samples_leaf`, `max_features`, and `max_depth`. These optimizations have enhanced the model's predictive capability, making it a robust tool for water quality assessment.
#
# </div>

# %% [markdown]
# ____
# <a id="rf_eval"></a>
# # <b><span style='color:#338aff'>Step 6.3 |</span><span style='color:#338aff'> Random Forest Model Evaluation</span></b>

# %%
cm = confusion_matrix(y_test, y_pred_best)
print("Confusion Matrix: of RandomForest\n", cm)

# Plotting the confusion matrix as a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Predicted Non-Potable', 'Predicted Potable'],
            yticklabels=['Actual Non-Potable', 'Actual Potable'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# Classification Report
print("Classification Report:\n", classification_report(y_test, y_pred_best))


# ROC AUC Curve
y_pred_proba = best_rf.predict_proba(X_test)[:, 1]
fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)
roc_auc = roc_auc_score(y_test, y_pred_proba)

plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label='ROC curve (AUC = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], 'k--')  # Random guessing line
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()
# Out:
# Confusion Matrix: of RandomForest
#  [[296  98]
#  [110 296]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.73      0.75      0.74       394
#            1       0.75      0.73      0.74       406
#
#     accuracy                           0.74       800
#    macro avg       0.74      0.74      0.74       800
# weighted avg       0.74      0.74      0.74       800

# %% [markdown]
# <a id="svc"></a>
# # <p style="background-color:#338aff; font-family:calibri; color:white; font-size:150%; text-align:center; border-radius:15px 50px;">Step 7 | SVC Model Building</p>
#
# ⬆️ [Table of Contents](#contents_tabel)

# %% [markdown]
# ____
# <a id="svc_base"></a>
# # <b><span style='color:#338aff'>Step 7.1 |</span><span style='color:#338aff'> SVC Model Definition</span></b>

# %%
    svc = SVC(random_state=42)
    svc.fit(X_train, y_train)
    
    y_pred = svc.predict(X_test)
    
    # Evaluate the model
    accuracy = accuracy_score(y_test, y_pred)
    print("Accuracy of SVC Base model:", accuracy)
# Out:
# Accuracy of SVC Base model: 0.67

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; font-size:120%; text-align:left ;background-color:#e2e5e9; color :black">
#
# The base __`SVC`__ model achieved an accuracy of **0.67**, reflecting its initial performance in predicting water quality.

# %% [markdown]
# ____
# <a id="svc_hp"></a>
# # <b><span style='color:#338aff'>Step 7.2 |</span><span style='color:#338aff'> SVC Hyperparameter Tuning</span></b>

# %%
# Define a more extensive parameter grid for SVC
param_grid_svc = {
    'C': [0.1, 1, 10, 100],  # Regularization parameter
    'kernel': ['linear', 'rbf', 'poly'],  # Multiple kernel options
    'gamma': ['scale', 'auto', 0.1, 1, 10],  # Various gamma options
}

# Initialize the SVC classifier
svc = SVC(random_state=42)

# Initialize the Random Search with cross-validation for SVC
random_search_svc = RandomizedSearchCV(estimator=svc,
                                       param_distributions=param_grid_svc,
                                       n_iter=20,  # Increased iterations for better coverage
                                       cv=5,  # Slightly increased folds for better estimation
                                       scoring='accuracy',
                                       random_state=42,
                                       n_jobs=-1)

# Fit the model to find the best hyperparameters
random_search_svc.fit(X_train, y_train)

# Get the best hyperparameters
best_params_svc = random_search_svc.best_params_
print("Best Hyperparameters for SVC:", best_params_svc)

# Create and train the best SVC model
best_svc = SVC(**best_params_svc, random_state=42)
best_svc.fit(X_train, y_train)

# Evaluate the best model on the test set
y_pred_best_svc = best_svc.predict(X_test)
accuracy_best_svc = accuracy_score(y_test, y_pred_best_svc)
print("Accuracy of SVC Model After Hyperparameter Tuning ):", accuracy_best_svc)
# Out:
# Best Hyperparameters for SVC: {'kernel': 'rbf', 'gamma': 1, 'C': 10}
# Accuracy of SVC Model After Hyperparameter Tuning ): 0.75625

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color: #e2e5e9; font-size:120%; text-align:left ;color :black">
#
# <h2 align="left"><font>Inference:</font></h2>
#
# After hyperparameter tuning, the __`SVC`__ model achieved an accuracy of **0.7562** , reflecting a substantial enhancement compared to the baseline. The selected hyperparameters, including `kernel: rbf`, `gamma: 1`, and `C: 10`, were crucial in improving the model's performance. This demonstrates the importance of fine-tuning parameters to optimize the SVC's predictive capabilities, making it an effective instrument for assessing water quality.
#
# </div>

# %% [markdown]
# ____
# <a id="svc_eval"></a>
# # <b><span style='color:#338aff'>Step 7.3 |</span><span style='color:#338aff'> SVC Model Evaluation</span></b>

# %%
cm = confusion_matrix(y_test, y_pred_best_svc)
print("Confusion Matrix (Best SVC Model):\n", cm)

# Plot the confusion matrix as a heatmap
plt.figure(figsize=(7,5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Non-Potable', 'Potable'], yticklabels=['Non-Potable', 'Potable'])
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix for Best SVC Model')
plt.show()

# Classification Report
cr = classification_report(y_test, y_pred_best_svc)
print("Classification Report:\n", cr)


# ROC AUC Curve
y_probs_svc = best_svc.decision_function(X_test)  # Use decision_function for SVC
fpr, tpr, thresholds = roc_curve(y_test, y_probs_svc)
roc_auc = roc_auc_score(y_test, y_probs_svc)

plt.figure(figsize=(7,5))
plt.plot(fpr, tpr, label='ROC Curve (AUC = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], 'k--')  # Diagonal line representing random guessing
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve for Best SVC Model')
plt.legend(loc='lower right')
plt.show()
# Out:
# Confusion Matrix (Best SVC Model):
#  [[333  61]
#  [134 272]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.71      0.85      0.77       394
#            1       0.82      0.67      0.74       406
#
#     accuracy                           0.76       800
#    macro avg       0.76      0.76      0.75       800
# weighted avg       0.77      0.76      0.75       800

# %% [markdown]
# <a id="xgb"></a>
# # <p style="background-color:#338aff; font-family:calibri; color:white; font-size:150%; text-align:center; border-radius:15px 50px;">Step 8 | XGBoost Model Building</p>
#
# ⬆️ [Table of Contents](#contents_tabel)

# %% [markdown]
# ____
# <a id="xgb_base"></a>
# # <b><span style='color:#338aff'>Step 8.1 |</span><span style='color:#338aff'> XGBoost Base Model Definition</span></b>

# %%
# Initialize the XGBoost classifier
xgb_classifier = XGBClassifier(random_state=42)
xgb_classifier.fit(X_train, y_train)
y_pred = xgb_classifier.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy of Xgboost Base model:", accuracy)
# Out:
# Accuracy of Xgboost Base model: 0.70875

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; font-size:120%; text-align:left; background-color:#e2e5e9; color:black">
#
# The base __`XGBoost`__ model achieved an accuracy of **0.7087** , reflecting its initial performance in predicting water quality.
#
# </div>

# %% [markdown]
# ____
# <a id="xgb_hp"></a>
# # <b><span style='color:#338aff'>Step 8.2 |</span><span style='color:#338aff'> XGBoost Hyperparameter Tuning</span></b>

# %%
# Define a broader parameter grid for RandomizedSearchCV
param_grid_xgb = {
    'learning_rate': [0.01, 0.05, 0.1, 0.2],
    'n_estimators': [200, 300, 400],
    'max_depth': [3, 5, 7, 10],
    'subsample': [0.6, 0.7, 0.8, 0.9],
    'colsample_bytree': [0.6, 0.7, 0.8, 0.9],
    'gamma': [0, 0.1, 0.2, 0.3]
}

# Initialize the XGBoost classifier
xgb_classifier = XGBClassifier(eval_metric='logloss', random_state=42)

# Initialize the Random Search with a broader parameter grid
random_search_xgb = RandomizedSearchCV(estimator=xgb_classifier,
                                       param_distributions=param_grid_xgb,
                                       n_iter=30,  # Increase iterations for better coverage
                                       cv=3,
                                       scoring='roc_auc',  # Change scoring to ROC AUC
                                       random_state=42,
                                       n_jobs=-1)

# Fit the model
random_search_xgb.fit(X_train, y_train)

# Get best hyperparameters and accuracy
best_params_xgb = random_search_xgb.best_params_
print("Best Hyperparameters for XGBoost:", best_params_xgb)

best_xgb = XGBClassifier(**best_params_xgb, random_state=42)
best_xgb.fit(X_train, y_train)

# Evaluate on test set
y_pred_best_xgb = best_xgb.predict(X_test)
accuracy_best_xgb = accuracy_score(y_test, y_pred_best_xgb)
print("Accuracy of xgboost After Hyperparameter tuning:", accuracy_best_xgb)
# Out:
# Best Hyperparameters for XGBoost: {'subsample': 0.9, 'n_estimators': 200, 'max_depth': 10, 'learning_rate': 0.05, 'gamma': 0, 'colsample_bytree': 0.9}
# Accuracy of xgboost After Hyperparameter tuning: 0.715

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color: #e2e5e9; font-size:120%; text-align:left ;color :black">
#
# <h2 align="left"><font>Inference:</font></h2>
#
# After hyperparameter tuning, the __`XGBoost`__ model achieved an accuracy of **0.715**, reflecting a notable improvement compared to its baseline performance. The optimal hyperparameters, including `subsample: 0.9`, `n_estimators: 200`, `max_depth: 10`, `learning_rate: 0.05`, `gamma: 0`, and `colsample_bytree: 0.9`, played a critical role in enhancing the model's effectiveness. This emphasizes the significance of fine-tuning parameters to maximize XGBoost's predictive capabilities, establishing it as a robust tool for water quality assessment.
#
# </div>

# %% [markdown]
# ____
# <a id="xgb_eval"></a>
# # <b><span style='color:#338aff'>Step 8.3 |</span><span style='color:#338aff'> XGBoost Model Evaluation</span></b>

# %%
# prompt: after this conf matrix with chart classification matrics and roc auc curve

# Confusion Matrix with Chart
cm_xgb = confusion_matrix(y_test, y_pred_best_xgb)
print("Confusion Matrix (Best XGBoost Model):\n", cm_xgb)

plt.figure(figsize=(7, 5))
sns.heatmap(cm_xgb, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Non-Potable', 'Potable'],
            yticklabels=['Non-Potable', 'Potable'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix (XGBoost)')
plt.show()


# Classification Report
from sklearn.metrics import classification_report

cr_xgb = classification_report(y_test, y_pred_best_xgb)
print("Classification Report (Best XGBoost Model):\n", cr_xgb)

# ROC AUC Curve
from sklearn.metrics import roc_curve, roc_auc_score

y_probs_xgb = best_xgb.predict_proba(X_test)[:, 1]
fpr_xgb, tpr_xgb, thresholds_xgb = roc_curve(y_test, y_probs_xgb)
roc_auc_xgb = roc_auc_score(y_test, y_probs_xgb)

plt.figure(figsize=(7, 5))
plt.plot(fpr_xgb, tpr_xgb, label='ROC Curve (AUC = %0.2f)' % roc_auc_xgb)
plt.plot([0, 1], [0, 1], 'k--')  # Diagonal line representing random guessing
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve (XGBoost)')
plt.legend(loc='lower right')
plt.show()
# Out:
# Confusion Matrix (Best XGBoost Model):
#  [[287 107]
#  [121 285]]
# Classification Report (Best XGBoost Model):
#                precision    recall  f1-score   support
#
#            0       0.70      0.73      0.72       394
#            1       0.73      0.70      0.71       406
#
#     accuracy                           0.71       800
#    macro avg       0.72      0.72      0.71       800
# weighted avg       0.72      0.71      0.71       800

# %% [markdown]
# <a id="dt"></a>
# # <p style="background-color:#338aff; font-family:calibri; color:white; font-size:150%; text-align:center; border-radius:15px 50px;">Step 9 | Deicision Tree Model Building</p>
#
# ⬆️ [Table of Contents](#contents_tabel)

# %% [markdown]
# ____
#
# <a id="dt_base"></a>
# # <b><span style='color:#338aff'>Step 9.1 |</span><span style='color:#338aff'> Decision Tree Base Model Definition</span></b>

# %%
# Initialize the Decision Tree classifier
dt_classifier = DecisionTreeClassifier(random_state=42)
dt_classifier.fit(X_train, y_train)

y_pred = dt_classifier.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy of Dicison Tree Base model:", accuracy)
# Out:
# Accuracy of Dicison Tree Base model: 0.64875

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color: #e2e5e9; font-size:120%; text-align:left ;color :black">
#
# The base __`Decision Tree`__ model achieved an accuracy of **0.64875**, reflecting its initial performance in predicting water quality. This result underscores the need for further optimization and hyperparameter tuning to enhance the model's predictive capabilities and overall effectiveness.
#
# </div>

# %% [markdown]
# ____
#
# <a id="dt_hp"></a>
# # <b><span style='color:#338aff'>Step 9.2 |</span><span style='color:#338aff'> Decision Tree Hyperparameter Tuning</span></b>

# %%
# Define a broader parameter grid for RandomizedSearchCV
param_grid_dt = {
    'max_depth': [None, 5, 10, 15, 20],  # Consider a range of depths
    'min_samples_split': [2, 5, 10, 15],
    'min_samples_leaf': [1, 2, 5, 10],
    'max_features': ['sqrt', 'log2', None],  # Use a variety of feature options
    'criterion': ['gini', 'entropy']  # Evaluate both criteria
}

# Initialize the Decision Tree classifier
dt_classifier = DecisionTreeClassifier(random_state=42)

# Initialize the Random Search with a broader parameter grid
random_search_dt = RandomizedSearchCV(estimator=dt_classifier,
                                       param_distributions=param_grid_dt,
                                       n_iter=30,  # Number of random combinations to try
                                       cv=3,  # Number of cross-validation folds
                                       scoring='accuracy',  # Use accuracy as the scoring metric
                                       random_state=42,
                                       n_jobs=-1)

# Fit the model
random_search_dt.fit(X_train, y_train)

# Get best hyperparameters
best_params_dt = random_search_dt.best_params_
print("Best Hyperparameters for Decision Tree:", best_params_dt)

# Use the best hyperparameters to create a new model
best_dt = DecisionTreeClassifier(**best_params_dt, random_state=42)
best_dt.fit(X_train, y_train)

# Evaluate on test set
y_pred_best_dt = best_dt.predict(X_test)
accuracy_best_dt = accuracy_score(y_test, y_pred_best_dt)
print(" Accuracy of Decision Tree After hyperparameter Tuning:", accuracy_best_dt)
# Out:
# Best Hyperparameters for Decision Tree: {'min_samples_split': 5, 'min_samples_leaf': 1, 'max_features': None, 'max_depth': None, 'criterion': 'gini'}
#  Accuracy of Decision Tree After hyperparameter Tuning: 0.64375

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color: #e2e5e9; font-size:120%; text-align:left ;color :black">
#
# <h2 align="left"><font>Summary :</font></h2>
#
# The __`Decision Tree`__ model experienced a slight decrease in accuracy to **0.64375** after hyperparameter tuning, indicating potential overfitting or underfitting. The chosen hyperparameters, while optimal based on the search, did not lead to the expected improvement in predictive performance. This suggests that further tuning or exploration of additional parameters may be necessary to enhance model effectiveness for water quality assessment.
#
# </div>

# %% [markdown]
# ____
#
# <a id="dt_eval"></a>
# # <b><span style='color:#338aff'>Step 9.3 |</span><span style='color:#338aff'> Decision Tree Model Evaluation</span></b>

# %%
# prompt: perfom using above code conf matrix with chart nad classification or roc auc

# Confusion Matrix with Chart for Decision Tree
cm_dt = confusion_matrix(y_test, y_pred_best_dt)
print("Confusion Matrix (Best Decision Tree Model):\n", cm_dt)

plt.figure(figsize=(7, 5))
sns.heatmap(cm_dt, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Non-Potable', 'Potable'],
            yticklabels=['Non-Potable', 'Potable'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix (Decision Tree)')
plt.show()


# Classification Report for Decision Tree

cr_dt = classification_report(y_test, y_pred_best_dt)
print("Classification Report (Best Decision Tree Model):\n", cr_dt)

# ROC AUC Curve for Decision Tree

y_probs_dt = best_dt.predict_proba(X_test)[:, 1]
fpr_dt, tpr_dt, thresholds_dt = roc_curve(y_test, y_probs_dt)
roc_auc_dt = roc_auc_score(y_test, y_probs_dt)

plt.figure(figsize=(7, 5))
plt.plot(fpr_dt, tpr_dt, label='ROC Curve (AUC = %0.2f)' % roc_auc_dt)
plt.plot([0, 1], [0, 1], 'k--')  # Diagonal line representing random guessing
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve (Decision Tree)')
plt.legend(loc='lower right')
plt.show()
# Out:
# Confusion Matrix (Best Decision Tree Model):
#  [[254 140]
#  [145 261]]
# Classification Report (Best Decision Tree Model):
#                precision    recall  f1-score   support
#
#            0       0.64      0.64      0.64       394
#            1       0.65      0.64      0.65       406
#
#     accuracy                           0.64       800
#    macro avg       0.64      0.64      0.64       800
# weighted avg       0.64      0.64      0.64       800

# %% [markdown]
# <a id="knn"></a>
# # <p style="background-color:#338aff; font-family:calibri; color:white; font-size:150%; text-align:center; border-radius:15px 50px;">Step 10 | KNN Model Building  </p>
#
# ⬆️ [Table of Contents](#contents_tabel)

# %% [markdown]
# ____
#
# <a id="knn_base"></a>
# # <b><span style='color:#338aff'>Step 10.1 |</span><span style='color:#338aff'> KNN Base Model Definition</span></b>

# %%
# prompt: knn base model

# Initialize the KNN classifier
knn_classifier = KNeighborsClassifier()
knn_classifier.fit(X_train, y_train)

# Make predictions on the test set
y_pred = knn_classifier.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy KNN Base Model:", accuracy)
# Out:
# Accuracy KNN Base Model: 0.67875

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color: #e2e5e9; font-size:120%; text-align:left ;color :black">
#
#
# The base __`KNN`__ model achieved an accuracy of **0.67875**, reflecting its initial capability in predicting water quality. This performance serves as a baseline for further model improvements.
#
# </div>

# %% [markdown]
# ____
#
# <a id="knn_hp"></a>
# # <b><span style='color:#338aff'>Step 10.2 |</span><span style='color:#338aff'> KNN Hyperparameter Tuning</span></b>

# %%
param_dist_knn = {
    'n_neighbors': np.arange(1, 30, 2),  # Odd numbers from 1 to 29
    'weights': ['uniform', 'distance'],
    'metric': ['euclidean', 'manhattan', 'minkowski', 'chebyshev'],
    'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute'],
    'leaf_size': np.arange(20, 60, 5)  # Leaf sizes from 20 to 55
}

# Initialize the KNN classifier
knn_classifier = KNeighborsClassifier()

# Initialize Randomized Search with cross-validation
random_search_knn = RandomizedSearchCV(estimator=knn_classifier,
                                       param_distributions=param_dist_knn,
                                       n_iter=50,  # Number of iterations
                                       cv=5,
                                       scoring='accuracy',
                                       n_jobs=-1,
                                       verbose=1,
                                       random_state=42)

# Fit the model to find the best hyperparameters
random_search_knn.fit(X_train, y_train)

# Get the best hyperparameters
best_params_knn = random_search_knn.best_params_
print("Best Hyperparameters for KNN:", best_params_knn)

# Create and train the best KNN model
best_knn = KNeighborsClassifier(**best_params_knn)
best_knn.fit(X_train, y_train)

# Evaluate the best model on the test set
y_pred_best_knn = best_knn.predict(X_test)
accuracy_best_knn = accuracy_score(y_test, y_pred_best_knn)
print("Accuracy of KNN After Hyperparameter Tuning):", accuracy_best_knn)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Best Hyperparameters for KNN: {'weights': 'uniform', 'n_neighbors': 1, 'metric': 'euclidean', 'leaf_size': 40, 'algorithm': 'kd_tree'}
# Accuracy of KNN After Hyperparameter Tuning): 0.735

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color: #e2e5e9; font-size:120%; text-align:left ;color :black">
#
# <h2 align="left"><font>Inference:</font></h2>
#
# After hyperparameter tuning, the __`KNN`__ model achieved an accuracy of **0.735**, reflecting a notable improvement compared to its base performance. The optimal hyperparameters, including `weights: uniform`, `n_neighbors: 1`, `metric: euclidean`, `leaf_size: 40`, and `algorithm: kd_tree`, were instrumental in enhancing the model's effectiveness. This highlights the importance of fine-tuning parameters to optimize KNN's predictive capabilities for water quality assessment.
#
# </div>

# %% [markdown]
# ____
#
# <a id="knn_eval"></a>
# # <b><span style='color:#338aff'>Step 10.3 |</span><span style='color:#338aff'> KNN Model Evaluation</span></b>

# %%
# Confusion Matrix with Chart for KNN
cm_knn = confusion_matrix(y_test, y_pred_best_knn)
print("Confusion Matrix (Best KNN Model):\n", cm_knn)

plt.figure(figsize=(7, 5))
sns.heatmap(cm_knn, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Non-Potable', 'Potable'],
            yticklabels=['Non-Potable', 'Potable'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix (KNN)')
plt.show()


# Classification Report for KNN

cr_knn = classification_report(y_test, y_pred_best_knn)
print("Classification Report (Best KNN Model):\n", cr_knn)

# ROC AUC Curve for KNN

y_probs_knn = best_knn.predict_proba(X_test)[:, 1]
fpr_knn, tpr_knn, thresholds_knn = roc_curve(y_test, y_probs_knn)
roc_auc_knn = roc_auc_score(y_test, y_probs_knn)

plt.figure(figsize=(7, 5))
plt.plot(fpr_knn, tpr_knn, label='ROC Curve (AUC = %0.2f)' % roc_auc_knn)
plt.plot([0, 1], [0, 1], 'k--')  # Diagonal line representing random guessing
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve (KNN)')
plt.legend(loc='lower right')
plt.show()
# Out:
# Confusion Matrix (Best KNN Model):
#  [[256 138]
#  [ 74 332]]
# Classification Report (Best KNN Model):
#                precision    recall  f1-score   support
#
#            0       0.78      0.65      0.71       394
#            1       0.71      0.82      0.76       406
#
#     accuracy                           0.73       800
#    macro avg       0.74      0.73      0.73       800
# weighted avg       0.74      0.73      0.73       800

# %% [markdown]
# <a id="feature"></a>
# # <p style="background-color:#338aff; font-family:calibri; color:white; font-size:150%; text-align:center; border-radius:15px 50px;">Step 11 | Feature Importance Visualization</p>
#
# ⬆️ [Table of Contents](#contents_tabel)

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
import numpy as np

# Load your water potability dataset
data = pd.read_csv("C:/Users/HP/Downloads/water_potability.csv")

# Separate features and target variable
X = data.drop('Potability', axis=1)  # Features
y = data['Potability']  # Target variable

# Train a Random Forest model
model = RandomForestClassifier(random_state=42)
model.fit(X, y)

# Get feature importances
importances = model.feature_importances_

# Create a DataFrame for better visualization
feature_importance_df = pd.DataFrame({
    'Feature': X.columns,
    'Importance': importances
})

# Sort the DataFrame
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

# Plot
plt.figure(figsize=(12, 8))
colors = plt.cm.viridis(np.linspace(0, 1, len(feature_importance_df)))
bars = plt.barh(feature_importance_df['Feature'], feature_importance_df['Importance'], color=colors)
plt.grid(axis='x', linestyle='--', alpha=0.7)

# Add data labels on the bars
for bar in bars:
    plt.text(bar.get_width(), bar.get_y() + bar.get_height()/2, 
             f"{bar.get_width():.3f}", va='center', ha='left', 
             fontsize=10, color='black')  # Change text color for contrast

plt.xlabel('Importance', fontsize=14)
plt.title('Feature Importances for Water Potability Dataset ', fontsize=16)
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; font-size:120%; text-align:left ;background-color:#e2e5e9; color :black">
#
# <h4 align="left"><font>Conclusion on Feature Importance:</font></h4>
# <ul>
#         <li>The feature importance analysis from the Random Forest model identifies key features that significantly influence water potability predictions.</li>
#         <li>Important parameters, such as pH and turbidity, are crucial for making accurate predictions.</li>
#         <li>Features with low importance scores can potentially be removed, simplifying the model and enhancing interpretability without sacrificing performance.</li>
#         <li>Understanding feature importance provides actionable insights for prioritizing water quality monitoring efforts.</li>
#         <li>This analysis informs regulatory decisions by ensuring focus on the most critical factors affecting water potability.</li>
#         <li>Overall, feature importance analysis is essential for improving model performance and guiding effective water quality management.</li>
#     </ul>
# </div>

# %% [markdown]
# <a id="conclusion"></a>
# # <p style="background-color:#338aff; font-family:calibri; color:white; font-size:150%; text-align:center; border-radius:15px 50px;">Step 12 | Conclusion</p>
#
# ⬆️ [Table of Contents](#contents_tabel)

# %%
# Displaying the accuracy of all models after hyperparameter tuning
print(f"Accuracy of Random Forest After Hyperparameter Tuning: {accuracy_best:.4f}")
print(f"Accuracy of SVC After Hyperparameter Tuning: {accuracy_best_svc:.4f}")
print(f"Accuracy of XGBoost After Hyperparameter Tuning: {accuracy_best_xgb:.4f}")
print(f"Accuracy of Decision Tree After Hyperparameter Tuning: {accuracy_best_dt:.4f}")
print(f"Accuracy of KNN After Hyperparameter Tuning: {accuracy_best_knn:.4f}")
# Out:
# Accuracy of Random Forest After Hyperparameter Tuning: 0.7400
# Accuracy of SVC After Hyperparameter Tuning: 0.7562
# Accuracy of XGBoost After Hyperparameter Tuning: 0.7150
# Accuracy of Decision Tree After Hyperparameter Tuning: 0.6438
# Accuracy of KNN After Hyperparameter Tuning: 0.7350

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; font-size:115%; text-align:left ;background-color:#e2e5e9; color :black">
#
# <h2>Conclusion :</h2>
# After tuning the hyperparameters for various models, the Support Vector Classifier (SVC) stands out as the best-performing model, achieving an accuracy of 0.7562%. This makes SVC the most reliable choice for predicting water quality in this dataset. Other models, such as Random Forest (0.74%) , XGBoost (0.71%), KNN(0.73%)  also performed well but did not surpass SVC's performance.
#
# * __`SVC`__: 0.7562% (Best Model)
# * __`XGBoost`__ : 0.7150%
# * __`Random Forest`__ :0.7400%
# * __`Decision Tree`__: 0.6438%
# * __`KNN`__: 0.7350%
#
# Overall, __`SVC`__ is the most suitable model for this dataset, providing the highest predictive accuracy.

# %% [markdown]
# <a id="pred"></a>
# # <p style="background-color:#338aff; font-family:calibri; color:white; font-size:150%; text-align:center; border-radius:15px 50px;">Step 13 | Prediction</p>
#
# ⬆️ [Table of Contents](#contents_tabel)

# %%
# Check against WHO limits
def check_water_quality(input_data):
    # Unpack the input data (assuming the order of features)
    pH, hardness, solids, chloramines, sulfate, conductivity, organic_carbon, trihalomethanes, turbidity = input_data
    
    # Check WHO limits
    if (6.5 <= pH <= 8.5 and
        hardness <= 200 and
        solids <= 1000 and
        chloramines <= 4 and
        sulfate <= 1000 and
        conductivity <= 400 and
        organic_carbon <= 10 and
        trihalomethanes <= 80 and
        turbidity <= 5):
        return "The water is Potable."
    else:
        return "The water is Not Potable."

# Example: Provide the actual input_data scaled back to its real values
input_data = [7.5, 150.0, 300.0, 3.0, 250.0, 300.0, 3.5, 75.0, 2.0]  # Example input values

# Get the result
result = check_water_quality(input_data)
print(result)
# Out:
# The water is Potable.
